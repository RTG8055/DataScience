# %% [markdown]
# # Cleveland Dot Plots

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import nan

# %%
df = pd.read_csv('../Datasets/titanic.csv')
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
ordered_df = df.iloc[:40, :].sort_values(by='fare')
my_range=range(0,ordered_df.shape[0])
ordered_df['age'] = ordered_df['age'].replace('?', nan)
ordered_df['fare'] = ordered_df['fare'].astype("float")
ordered_df['age'] = ordered_df['age'].astype("float")
ordered_df = ordered_df.sort_values(by='fare')

# %%
my_range
# Out:
# range(0, 40)

# %%
ordered_df.head()
# Out:
#     pclass  survived                                           name   sex  \
# 7        1         0                         Andrews, Mr. Thomas Jr  male
# 15       1         0                            Baumann, Mr. John D  male
# 25       1         0                            Birnbaum, Mr. Jakob  male
# 37       1         1  Bradley, Mr. George ('George Arthur Brayton')  male
# 29       1         1      Bjornstrom-Steffansson, Mr. Mauritz Hakan  male
#
#      age  sibsp  parch    ticket    fare cabin embarked boat body  \
# 7   39.0      0      0    112050   0.000   A36        S    ?    ?
# 15   NaN      0      0  PC 17318  25.925     ?        S    ?    ?
# 25  25.0      0      0     13905  26.000     ?        C    ?  148
# 37   NaN      0      0    111427  26.550     ?        S    9    ?
# 29  28.0      0      0    110564  26.550   C52        S    D    ?
#
#                              home.dest
# 7                          Belfast, NI
# 15                        New York, NY
# 25                   San Francisco, CA
# 37                     Los Angeles, CA
# 29  Stockholm, Sweden / Washington, DC

# %% [markdown]
# ## Cleveland Dot Plot

# %% [markdown]
# ##### matplotlib

# %%
plt.figure(figsize=(20,10))
plt.hlines(y=my_range, xmin=0, xmax=ordered_df['fare'], color='skyblue')
plt.grid(True)
plt.plot(ordered_df['fare'], my_range, "o")
plt.yticks(my_range, ordered_df['name'])
plt.title("Ticket Price Dot Plot", loc='left')
plt.xlabel('Ticket Price')
plt.ylabel('Name')
# Out:
# Text(0, 0.5, 'Name')

# %% [markdown]
# ## Multiple Dots
# ##### matplotlib
# Sorting has to be done through dataframe only.

# %%
plt.figure(figsize=(20,10))
plt.hlines(y=my_range, xmin=0, xmax=ordered_df['fare'], color='skyblue')
plt.hlines(y=my_range, xmin=0, xmax=ordered_df['age'], color='red')

plt.grid(True)
plt.plot(ordered_df['fare'], my_range, "o")
plt.plot(ordered_df['age'], my_range, "o")

plt.yticks(my_range, ordered_df['name'])
plt.title("Ticket Price Dot Plot", loc='left')
plt.xlabel('Ticket Price')
plt.ylabel('Name')
# Out:
# Text(0, 0.5, 'Name')
